# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 4.1.2 Linear Regression

# %% [markdown]
# ## Prediction of House Price Using Linear Regression

# %% [markdown]
# ### Data
#
# The Sacramento real estate transactions file is a list of 985 real estate transactions in the Sacramento area reported over a five-day period, as reported by the Sacramento Bee.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ### 1. Explore Data

# %% [markdown]
# Perform EDA on this dataset. Find Dependent and Independent Variables to predict house price.

# %%
# Read CSV
path = r'C:\Users\Nour\Downloads'
house_csv = "\Sacramento_transactions (1).csv"

house = pd.read_csv(path+house_csv)

# %%
house.head()
# Out:
#              street        city    zip state  beds  baths  sq__ft  \
# 0      3526 HIGH ST  SACRAMENTO  95838    CA     2      1     836
# 1       51 OMAHA CT  SACRAMENTO  95823    CA     3      1    1167
# 2    2796 BRANCH ST  SACRAMENTO  95815    CA     2      1     796
# 3  2805 JANETTE WAY  SACRAMENTO  95815    CA     2      1     852
# 4   6001 MCMAHON DR  SACRAMENTO  95824    CA     2      1     797
#
#           type                     sale_date  price   latitude   longitude
# 0  Residential  Wed May 21 00:00:00 EDT 2008  59222  38.631913 -121.434879
# 1  Residential  Wed May 21 00:00:00 EDT 2008  68212  38.478902 -121.431028
# 2  Residential  Wed May 21 00:00:00 EDT 2008  68880  38.618305 -121.443839
# 3  Residential  Wed May 21 00:00:00 EDT 2008  69307  38.616835 -121.439146
# 4  Residential  Wed May 21 00:00:00 EDT 2008  81900  38.519470 -121.435768

# %%
house.describe()
# Out:
#                 zip        beds       baths       sq__ft          price  \
# count    985.000000  985.000000  985.000000   985.000000     985.000000
# mean   95750.697462    2.911675    1.776650  1314.916751  234144.263959
# std       85.176072    1.307932    0.895371   853.048243  138365.839085
# min    95603.000000    0.000000    0.000000     0.000000    1551.000000
# 25%    95660.000000    2.000000    1.000000   952.000000  145000.000000
# 50%    95762.000000    3.000000    2.000000  1304.000000  213750.000000
# 75%    95828.000000    4.000000    2.000000  1718.000000  300000.000000
# max    95864.000000    8.000000    5.000000  5822.000000  884790.000000
#
#          latitude   longitude
# count  985.000000  985.000000
# mean    38.607732 -121.355982
# std      0.145433    0.138278
# min     38.241514 -121.551704
# 25%     38.482717 -121.446127
# 50%     38.626582 -121.376220
# 75%     38.695589 -121.295778
# max     39.020808 -120.597599

# %% [markdown]
# ### 2. Predict Price

# %% [markdown]
# We are going to predict `price` from available information.

# %% [markdown]
# #### 2.1 What is the Target Variable? Why?

# %%
# ANSWER
target = house[['price']]
target
# Out:
#       price
# 0     59222
# 1     68212
# 2     68880
# 3     69307
# 4     81900
# ..      ...
# 980  232425
# 981  234000
# 982  235000
# 983  235301
# 984  235738
#
# [985 rows x 1 columns]

# %% [markdown]
# price (what we are trying to predict)

# %% [markdown]
# #### 2.2 List all possible variables which might be Independent/Predictor variable.

# %%
# ANSWER
predictors = house.loc[:,['beds', 'baths', 'sq__ft','zip']]
predictors
# Out:
#      beds  baths  sq__ft    zip
# 0       2      1     836  95838
# 1       3      1    1167  95823
# 2       2      1     796  95815
# 3       2      1     852  95815
# 4       2      1     797  95824
# ..    ...    ...     ...    ...
# 980     4      3    2280  95829
# 981     3      2    1477  95823
# 982     3      2    1216  95610
# 983     4      2    1685  95758
# 984     3      2    1362  95762
#
# [985 rows x 4 columns]

# %% [markdown]
# #### 2.3 Find correlation between variables
#
# Find correlation between variables. Which is the best predictor? Why? State your reason.

# %%
# ANSWER
data = predictors
data['price'] = target

data.corr()
# Out:
#             beds     baths    sq__ft       zip     price
# beds    1.000000  0.839650  0.684041  0.125319  0.342024
# baths   0.839650  1.000000  0.665690  0.069165  0.416208
# sq__ft  0.684041  0.665690  1.000000  0.130108  0.333897
# zip     0.125319  0.069165  0.130108  1.000000 -0.093353
# price   0.342024  0.416208  0.333897 -0.093353  1.000000

# %% [markdown]
# #### 2.4 Find Coefficient and Intercept using Linear Regression
#
# Using LinearRegression of sklearn.linear_model package find Coefficient and Intercept.
#
# Create an instance of LinearRegression.
#
# Explore following methods:
#
# - fit
# - predict
# - score

# %%
from sklearn.linear_model import LinearRegression as reg

# %% [markdown]
# ##### 2.4.1 Fit predictor and target variables using linear regression

# %%
# ANSWER

X = data[['sq__ft','baths']]
Y = data['price']
reg = reg()
reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
print(f'Intercept:{reg.intercept_}\nSlope: {reg.coef_}\n{reg.score}')
# Out:
# Intercept:116758.58835021191
# Slope: [1.65538727e+01 5.38196745e+04]
# <bound method RegressorMixin.score of LinearRegression()>

# %%
reg.predict(X)
# Out:
# array([184417.30045728, 189896.63231339, 183755.14555019, 184682.16242011,
#        183771.69942287, 189151.70804293, 242673.41288376, 190062.17104017,
#        239975.13163739, 243368.6755362 , 239445.40771173, 245735.87932902,
#        184996.68600098, 187463.21302986, 241315.99532424, 243170.02906407,
#        184549.73143869, 183738.59167752, 180311.94003336, 246844.98879838,
#        242905.16710124, 246398.0342361 , 244924.73956784, 250900.68760427,
#        239312.97673031, 242408.55092092, 186519.64228727, 242921.72097391,
#        247242.28174263, 245057.17054926, 241597.41115975, 243467.99877226,
#        247242.28174263, 242872.05935588, 241597.41115975, 247871.32890436,
#        242309.22768486, 248765.23802893, 243368.6755362 , 183159.20613382,
#        245984.18741918, 244378.4617695 , 241878.82699526, 241663.62665046,
#        250668.93338679, 189118.60029757, 250553.05627805, 202941.08398294,
#        251811.15060151, 248848.00739231, 244063.93818863, 250718.59500482,
#        248616.25317483, 252771.27521678, 244014.2765706 , 247672.68243224,
#        256562.11205984, 243799.0762258 , 189648.32422324, 308858.83032256,
#        244510.89275091, 243103.81357336, 250933.79534962, 195061.44058865,
#        247904.43664972, 245586.89447493, 250652.37951411, 246944.31203445,
#        367826.75927416, 245355.14025745, 252787.82908946, 254525.98572055,
#        186072.68772499, 116758.58835021, 249410.83906333, 250718.59500482,
#        250817.91824089, 246596.68070823, 313576.68403553, 251148.99569443,
#        248864.56126499, 245702.77158366, 245537.23285689, 248367.94508468,
#        192263.83610622, 245288.92476674, 253201.67590639, 249510.1622994 ,
#        248401.05283003, 247838.22115901, 185278.10183649, 255552.32582653,
#        245951.07967382, 247871.32890436, 224397.93744825, 246232.49550933,
#        253698.2920867 , 251331.08829387, 116758.58835021, 187794.2904834 ,
#        186469.98066924, 224397.93744825, 194680.70151707, 248401.05283003,
#        246878.09654374, 246398.0342361 , 252787.82908946, 245288.92476674,
#        315960.44170103, 248848.00739231, 244527.44662359, 252291.21290915,
#        246944.31203445])

# %% [markdown]
# ##### 2.4.2 Find R Score

# %% [markdown]
# Find $R^2$ Using ```score``` method of Linear Regression.

# %%
# ANSWER
reg.score(X, Y)
# Out:
# 0.17902920726797467

# %% [markdown]
# ### 3. Splitting Data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### 3.1 Create training and testing subsets
#
# Hint: Using `train_test_split` Library.
#
# ```
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# ```

# %%
# ANSWER
## Create training and testing subsets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)
#X_train, X_test, _train, Y_test = train_test_split(X, Y, test_size=0.33, random_state=42)

# %% [markdown]
# #### 3.2 Check Shape, Sample of Test Train Data

# %%
# ANSWER
## Check training/test data
print(f'training feature data{X_train.shape}\ntest feature data {X_test.shape}\ntraining target data{Y_train.shape}\ntest target data {Y_test.shape}')
# Out:
# training feature data(659, 2)
# test feature data (326, 2)
# training target data(659,)
# test target data (326,)

# %% [markdown]
# #### 3.3 Using Linear Regression Find The Score
#
# 1. Fit model using X_train, y_train
# 2. Find score using X_test, y_test

# %%
# ANSWER
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
# ANSWER
reg.score(X_test, Y_test)
# Out:
# 0.16805880122516081

# %% [markdown]
# ### 4. Predict House Price
#
# Let's assume we have information of following house:
#
# - street:	1140 EDMONTON DR
# - city:	SACRAMENTO
# - zip:	95833
# - state:	CA
# - beds:	3
# - baths:	2
# - sq__ft:	1204
# - type:	Residential
#
# **Predict the price of this house using linear regression model.**

# %%
# ANSWER

reg.predict([[1204,2]])
# Out:
# array([240195.82959119])

# %% [markdown]
# #### Find the error

# %%
# Predict price from X_test
y_pred = reg.predict(X_test)
def residual_fit_graph(x, y, y_pred, graphWidth=1000, graphHeight=600):
    f = plt.figure(figsize=(graphWidth/100.0, graphHeight/100.0), dpi=100)
    axes = f.add_subplot(111)
    if isinstance(x, pd.DataFrame):
        x = x.values
    # first the raw data as a scatter plot
    axes.plot(x, y,  'D', alpha = 1)
    # now the model as a line plot
    axes.plot(x, y_pred, color = 'orange')
    # now add individual line for each point
    for X,Y,Y_pred in zip(x, y, y_pred):
        lineXdata = (X, X) # same X
        lineYdata = (Y, Y_pred) # different Y
        plt.plot(lineXdata, lineYdata, alpha = 0.5)
    axes.set_xlabel('X Data') # X axis data label
    axes.set_ylabel('Y Data') # Y axis data label
    plt.show()
    plt.close('all')
residual_fit_graph(X_test, y_test, y_pred)

# %%
list(zip(X_test,y_test,y_pred))
# Out:
# [('sq__ft', 77000, 178638.9052364626), ('baths', 236000, 367730.7540573366)]

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
