# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# ## Lab 4.2.1: Feature Selection

# %% [markdown]
# ### 1. Load & Explore Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# #### 1.1 Load Data

# %%
# Read CSV
wine_csv =pd.read_csv(r'C:\Users\Nour\Downloads\winequality_merged.csv')

# %% [markdown]
# #### 1.2 Explore Data (Exploratory Data Analysis)

# %%
# ANSWER
wine_csv.head(20)
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4             0.700         0.00             1.9      0.076
# 1             7.8             0.880         0.00             2.6      0.098
# 2             7.8             0.760         0.04             2.3      0.092
# 3            11.2             0.280         0.56             1.9      0.075
# 4             7.4             0.700         0.00             1.9      0.076
# 5             7.4             0.660         0.00             1.8      0.075
# 6             7.9             0.600         0.06             1.6      0.069
# 7             7.3             0.650         0.00             1.2      0.065
# 8             7.8             0.580         0.02             2.0      0.073
# 9             7.5             0.500         0.36             6.1      0.071
# 10            6.7             0.580         0.08             1.8      0.097
# ...

# %%
wine_csv.quality.unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9], dtype=int64)

# %%
wine_csv.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# ### 2. Set Target Variable

# %% [markdown]
# Create a target variable for wine quality.

# %%
# Target Variable
target =wine_csv[['quality']]
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 6492        6
# 6493        5
# 6494        6
# 6495        7
# 6496        6
#
# [6497 rows x 1 columns]

# %% [markdown]
# ### 3. Set Predictor Variables

# %% [markdown]
# Create a predictor matrix with variables of your choice. State your reason.

# %%
# ANSWER
predictors = wine_csv.loc[:,['volatile acidity', 'free sulfur dioxide', 'pH','sulphates']]
predictors
# Out:
#       volatile acidity  free sulfur dioxide    pH  sulphates
# 0                 0.70                 11.0  3.51       0.56
# 1                 0.88                 25.0  3.20       0.68
# 2                 0.76                 15.0  3.26       0.65
# 3                 0.28                 17.0  3.16       0.58
# 4                 0.70                 11.0  3.51       0.56
# ...                ...                  ...   ...        ...
# 6492              0.21                 24.0  3.27       0.50
# 6493              0.32                 57.0  3.15       0.46
# 6494              0.24                 30.0  2.99       0.46
# 6495              0.29                 20.0  3.34       0.38
# 6496              0.21                 22.0  3.26       0.32
#
# [6497 rows x 4 columns]

# %% [markdown]
# ### 4. Using Linear Regression Create a Model and Test Score

# %%
from sklearn.linear_model import LinearRegression as reg
from sklearn.model_selection import train_test_split

# %%
# Train-Test Split


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

# %%
# Create a model for Linear Regression
X = wine_csv['free sulfur dioxide'].values.reshape(-1,1)
Y = wine_csv['quality']
reg = reg()


# Fit the model with the Training data
reg.fit(X,Y)

# Calculate the score (R^2 for Regression) for Training Data
reg.score(X_train, y_train)

# Calculate the score (R^2 for Regression) for Testing Data
reg.score(X_test, y_test)
# Out:
# 0.0006061819102542998

# %% [markdown]
# ### BONUS: Cross validation

# %%
# Cross validation 
from sklearn.model_selection import KFold 
from sklearn.metrics import mean_squared_error

# %%
# Set up 5-fold cross validation  
k_fold = KFold(5, shuffle=True)
train_scores = []
train_rmse = []
test_scores = []
test_rmse = []

for k, (train, test) in enumerate(k_fold.split(X)):
    
    # Get training and test sets for X and y
    x_trainn = train.reshape(-1,1)
    # Fit model with training set
    reg.fit(X_train,Y_train)
    # Make predictions with training and test set
    Y_train_predict = reg.predict(train)
    Y_test_predict = reg.predict(test)
    
    # Score R2 and RMSE on training and test sets and store in list
    train_score.append(reg.score(X_train,Y_train))
    
# Create a metrics_df dataframe to display r2 and rmse scores

# %%
# Describe the metrics

# %% [markdown]
# ### 5. Feature Selection
#
# What's your score (R^2 for Regression) for Testing Data?
#
# How many feature have you selected? Can you improve your score by selecting different features?

# %% [markdown]
# **Please continue with Lab 4.2.2 with the same dataset.**

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2021 Institute of Data
#
#
# ---
#
#
#
# ---
